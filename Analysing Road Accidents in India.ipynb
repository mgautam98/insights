# %% [markdown]
# # Analysing Road Accidents in India
#
# Road Accidents in India are a major source of deaths, injuries and property damage every year. The National Crime Records Bureau (NCRB) 2016 report states there were 496,762 roads, railways and railway crossing-related traffic collisions in 2015.[2] Of these, road collisions accounted for 464,674 collisions which caused 148,707 traffic-related deaths in India.
#
# ## Data set
# Data Set from **data.gov.in** for the year 2016 to 2018 "State/UT-wise Total number of Fatal Road Accidents, Total Road Accidents, Persons Killed and Injured on Other Roads from 2016 to 2018"

# %% [markdown]
# ## Data Wrangling

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Gathering
#
# - Server Logs
# - APIs
# - CSV/JSON files from hosted/local
# - Web Scraping
#
# Any combination of these
# We will be using Hosted CSV file

# %% [markdown]
# Data Link : http://www.sharecsv.com/dl/f471c9b676935fab5ffc3877ed2d3588/Road-Accidents-2018-Annexure-19.csv

# %%
# url from where we will fetch the data
url = "http://www.sharecsv.com/dl/f471c9b676935fab5ffc3877ed2d3588/Road-Accidents-2018-Annexure-19.csv"

# fetch file from server convert it to utf-8 encoding
# and make a dataframe object
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   S.No           State/UT  Fatal Accidents - 2016  Fatal Accidents - 2017  \
# 0    1     Andhra Pradesh                    3328                    3192
# 1    2  Arunachal Pradesh                      37                      33
# 2    3              Assam                     616                     710
# 3    4              Bihar                    1299                    1422
# 4    5       Chhattisgarh                    1622                    1836
#
#    Fatal Accidents - 2018  Accidents - 2016  Accidents - 2017  \
# 0                    2619             11078             11526
# 1                      46                79                83
# 2                     716              1958              2277
# 3                    2075              2650              2714
# 4                    2049              6374              6483
#
#    Accidents - 2018 - Number  Accidents - 2018 - Rank  Killed - 2016  \
# 0                       9955                      9.0           3518
# 1                         94                     28.0             47
# 2                       2174                     18.0            596
# 3                       3495                     16.0           1451
# 4                       6733                     11.0           1801
#
#    Killed - 2017  Killed - 2018 - Number  Killed - 2018 - Rank  \
# 0           3350                    2730                   9.0
# 1             35                      61                  28.0
# 2            762                     744                  19.0
# 3           1600                    2204                  10.0
# 4           2020                    2140                  12.0
#
#    Injured - 2016  Injured - 2017  Injured - 2018
# 0           13707           12793            9121
# 1             148             107             109
# 2            1697            1880            1976
# 3            1954            1966            2455
# 4            5954            6027            6257

# %% [markdown]
# ### Data Assessment

# %%
df.shape
# Out:
# (37, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 16 columns):
# S.No                         37 non-null object
# State/UT                     37 non-null object
# Fatal Accidents - 2016       37 non-null int64
# Fatal Accidents - 2017       37 non-null int64
# Fatal Accidents - 2018       37 non-null int64
# Accidents - 2016             37 non-null int64
# Accidents - 2017             37 non-null int64
# Accidents - 2018 - Number    37 non-null int64
# Accidents - 2018 - Rank      36 non-null float64
# Killed - 2016                37 non-null int64
# Killed - 2017                37 non-null int64
# Killed - 2018 - Number       37 non-null int64
# Killed - 2018 - Rank         36 non-null float64
# Injured - 2016               37 non-null int64
# Injured - 2017               37 non-null int64
# Injured - 2018               37 non-null int64
# dtypes: float64(2), int64(12), object(2)
# memory usage: 4.8+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# S.No                         0
# State/UT                     0
# Fatal Accidents - 2016       0
# Fatal Accidents - 2017       0
# Fatal Accidents - 2018       0
# Accidents - 2016             0
# Accidents - 2017             0
# Accidents - 2018 - Number    0
# Accidents - 2018 - Rank      1
# Killed - 2016                0
# Killed - 2017                0
# Killed - 2018 - Number       0
# Killed - 2018 - Rank         1
# Injured - 2016               0
# Injured - 2017               0
# Injured - 2018               0
# dtype: int64

# %%
df.describe()
# Out:
#        Fatal Accidents - 2016  Fatal Accidents - 2017  Fatal Accidents - 2018  \
# count               37.000000               37.000000               37.000000
# mean              2819.891892             2788.432432             2851.189189
# std               8502.177962             8408.275958             8590.493799
# min                  1.000000                0.000000                1.000000
# 25%                 44.000000               33.000000               62.000000
# 50%                633.000000              945.000000             1171.000000
# 75%               2975.000000             2673.000000             2619.000000
# max              52168.000000            51586.000000            52747.000000
#
#        Accidents - 2016  Accidents - 2017  Accidents - 2018 - Number  \
# count         37.000000         37.000000                  37.000000
# mean       11710.162162      11204.648649               11277.351351
# std        35539.753992      33981.301403               34181.140475
# min            1.000000          1.000000                   3.000000
# 25%          137.000000         99.000000                 178.000000
# 50%         2650.000000       2277.000000                2174.000000
# 75%        10933.000000      11526.000000                9955.000000
# max       216638.000000     207286.000000              208631.000000
#
#        Accidents - 2018 - Rank  Killed - 2016  Killed - 2017  \
# count                36.000000      37.000000      37.000000
# mean                 18.500000    3061.783784    2968.648649
# std                  10.535654    9230.858592    8953.338729
# min                   1.000000       1.000000       0.000000
# 25%                   9.750000      46.000000      35.000000
# 50%                  18.500000     823.000000     971.000000
# 75%                  27.250000    3207.000000    2768.000000
# max                  36.000000   56643.000000   54920.000000
#
#        Killed - 2018 - Number  Killed - 2018 - Rank  Injured - 2016  \
# count               37.000000             36.000000       37.000000
# mean              3069.783784             18.472222    11938.810811
# std               9251.801702             10.500302    36312.520686
# min                  1.000000              1.000000        0.000000
# 25%                 64.000000              9.750000      162.000000
# 50%               1237.000000             18.500000     1811.000000
# 75%               2730.000000             27.250000     9857.000000
# max              56791.000000             36.000000   220868.000000
#
#        Injured - 2017  Injured - 2018
# count       37.000000       37.000000
# mean     11284.918919    11200.918919
# std      34331.619058    34055.523876
# min          1.000000        3.000000
# 25%        118.000000      167.000000
# 50%       1880.000000     1976.000000
# 75%       9039.000000     9121.000000
# max     208771.000000   207217.000000

# %%
df
# Out:
#      S.No           State/UT  Fatal Accidents - 2016  Fatal Accidents - 2017  \
# 0       1     Andhra Pradesh                    3328                    3192
# 1       2  Arunachal Pradesh                      37                      33
# 2       3              Assam                     616                     710
# 3       4              Bihar                    1299                    1422
# 4       5       Chhattisgarh                    1622                    1836
# 5       6                Goa                     179                     154
# 6       7            Gujarat                    2975                    2673
# 7       8            Haryana                    1619                    1777
# 8       9   Himachal Pradesh                     328                     320
# 9      10    Jammu & Kashmir                     375                     347
# 10     11          Jharkhand                     633                     945
# 11     12          Karnataka                    3697                    3505
# 12     13             Kerala                    2072                    1912
# 13     14     Madhya Pradesh                    4045                    4285
# 14     15        Maharashtra                    5070                    4729
# 15     16            Manipur                      18                       9
# 16     17          Meghalaya                      50                      18
# 17     18            Mizoram                       8                      14
# 18     19           Nagaland                       9                      11
# 19     20             Orissa                    1090                    1103
# 20     21             Punjab                    1827                    1386
# 21     22          Rajasthan                    4453                    4164
# 22     23             Sikkim                       7                      17
# 23     24         Tamil Nadu                    4988                    4424
# 24     25          Telangana                    3370                    3101
# 25     26            Tripura                      44                      31
# 26     27        Uttarakhand                     102                     148
# 27     28      Uttar Pradesh                    4407                    5602
# 28     29        West Bengal                    2298                    2184
# 29     30      A & N Islands                       8                       5
# 30     31         Chandigarh                     120                      88
# 31     32       D & N Haveli                      40                      40
# 32     33        Daman & Diu                      30                      31
# 33     34              Delhi                    1327                    1300
# 34     35        Lakshadweep                       1                       0
# 35     36         Puducherry                      76                      70
# 36  Total              Total                   52168                   51586
#
#     Fatal Accidents - 2018  Accidents - 2016  Accidents - 2017  \
# 0                     2619             11078             11526
# 1                       46                79                83
# 2                      716              1958              2277
# 3                     2075              2650              2714
# 4                     2049              6374              6483
# 5                      127              2510              1920
# 6                     3137             10933              9324
# 7                     1478              4529              4575
# 8                      359               873               877
# 9                      387              2842              2783
# 10                    1199              1293              1692
# 11                    3740             18008             17132
# 12                    2105             23076             22433
# 13                    4509             28807             27898
# 14                    5450             20462             18108
# 15                      14                96                62
# 16                      88               180               136
# 17                      13                10                16
# 18                      10                18                71
# 19                    1591              2990              2923
# 20                    1171              2737              2139
# 21                    4231             12804             11893
# 22                       4                50                63
# 23                    3322             25453             22339
# 24                    3134             12555             12378
# 25                      62               137                99
# 26                     133               181               363
# 27                    5341             10819             12921
# 28                    1983              5319              5015
# 29                       5               129                79
# 30                      80               381               309
# 31                      30                70                67
# 32                      34                65                70
# 33                    1399              6652              5918
# 34                       1                 1                 1
# 35                     105               519               599
# 36                   52747            216638            207286
#
#     Accidents - 2018 - Number  Accidents - 2018 - Rank  Killed - 2016  \
# 0                        9955                      9.0           3518
# 1                          94                     28.0             47
# 2                        2174                     18.0            596
# 3                        3495                     16.0           1451
# 4                        6733                     11.0           1801
# 5                        1953                     20.0            188
# 6                        9820                     10.0           3207
# 7                        3654                     15.0           1936
# 8                        1005                     22.0            433
# 9                        3196                     17.0            485
# 10                       2092                     19.0            823
# 11                      17384                      5.0           3921
# 12                      23468                      2.0           2139
# 13                      27520                      1.0           4042
# 14                      18607                      4.0           5412
# 15                         66                     31.0             19
# 16                        272                     25.0             20
# 17                         17                     35.0              8
# 18                         75                     30.0             11
# 19                       3951                     14.0           1184
# 20                       1731                     21.0           1998
# 21                      11513                      8.0           4800
# 22                         32                     34.0             11
# 23                      21488                      3.0           5138
# 24                      12222                      7.0           3608
# 25                        178                     27.0             44
# 26                        310                     24.0            154
# 27                      12582                      6.0           5641
# 28                       6166                     12.0           2358
# 29                         60                     32.0              9
# 30                        270                     26.0            127
# 31                         47                     33.0             46
# 32                         76                     29.0             36
# 33                       5732                     13.0           1353
# 34                          3                     36.0              1
# 35                        690                     23.0             78
# 36                     208631                      NaN          56643
#
#     Killed - 2017  Killed - 2018 - Number  Killed - 2018 - Rank  \
# 0            3350                    2730                   9.0
# 1              35                      61                  28.0
# 2             762                     744                  19.0
# 3            1600                    2204                  10.0
# 4            2020                    2140                  12.0
# 5             165                     133                  23.0
# 6            2768                    3348                   8.0
# 7            1761                    1544                  15.0
# 8             418                     497                  20.0
# 9             415                     476                  21.0
# 10            971                    1281                  17.0
# 11           3715                    3946                   5.0
# 12           1985                    2179                  11.0
# 13           4683                    4925                   3.0
# 14           5005                    5727                   2.0
# 15             10                      16                  31.0
# 16             20                     103                  25.0
# 17             16                      16                  31.0
# 18              7                      14                  33.0
# 19           1115                    1841                  14.0
# 20           1485                    1237                  18.0
# 21           4405                    4521                   4.0
# 22             21                       9                  34.0
# 23           4574                    3439                   6.0
# 24           3285                    3374                   7.0
# 25             30                      64                  27.0
# 26            179                     150                  22.0
# 27           6216                    6259                   1.0
# 28           2340                    2126                  13.0
# 29              5                       5                  35.0
# 30             91                      82                  26.0
# 31             43                      32                  30.0
# 32             31                      35                  29.0
# 33           1317                    1427                  16.0
# 34              0                       1                  36.0
# 35             77                     105                  24.0
# 36          54920                   56791                   NaN
#
#     Injured - 2016  Injured - 2017  Injured - 2018
# 0            13707           12793            9121
# 1              148             107             109
# 2             1697            1880            1976
# 3             1954            1966            2455
# 4             5954            6027            6257
# 5             1384             963             829
# 6             9857            8839            8938
# 7             4975            3994            3968
# 8             1811            1595            1845
# 9             4095            3813            4289
# 10            1010            1566            1503
# 11           21252           20816           20515
# 12           25585           24768           26241
# 13           29820           30119           28915
# 14           18162           16003           15880
# 15             162              96              98
# 16             111              79             167
# 17               6              26              15
# 18              35              34              68
# 19            3194            2919            4049
# 20            1739            1392             896
# 21           13193           11434           11046
# 22              86             152              73
# 23           27990           24352           23782
# 24           12975           12681           12563
# 25             166             118             225
# 26             185             349             385
# 27            7896            9039            9207
# 28            4021            3851            5258
# 29             136              95              63
# 30             307             273             265
# 31             130              60              43
# 32              86              68              94
# 33            6504            5844            5382
# 34               0               1               3
# 35             535             659             694
# 36          220868          208771          207217

# %% [markdown]
# ### Cleaning Data
# - Drop rank columns and s.no
# - Drop Total row
# - Change column name for 2018 Accidents and Killed
# - Change column names without spaces and '-'
#
#
#
#
# **1. Drop Rank Columns and S.NO**

# %%
df = df.drop(['Accidents - 2018 - Rank', 'Killed - 2018 - Rank', 'S.No'], axis=1)

# %%
# Check if worked
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 13 columns):
# State/UT                     37 non-null object
# Fatal Accidents - 2016       37 non-null int64
# Fatal Accidents - 2017       37 non-null int64
# Fatal Accidents - 2018       37 non-null int64
# Accidents - 2016             37 non-null int64
# Accidents - 2017             37 non-null int64
# Accidents - 2018 - Number    37 non-null int64
# Killed - 2016                37 non-null int64
# Killed - 2017                37 non-null int64
# Killed - 2018 - Number       37 non-null int64
# Injured - 2016               37 non-null int64
# Injured - 2017               37 non-null int64
# Injured - 2018               37 non-null int64
# dtypes: int64(12), object(1)
# memory usage: 3.9+ KB

# %% [markdown]
# **2. Drop Total row**

# %%
df = df.drop([36], axis=0)

# %%
# Check if worked
df.tail()
# Out:
#         State/UT  Fatal Accidents - 2016  Fatal Accidents - 2017  \
# 31  D & N Haveli                      40                      40
# 32   Daman & Diu                      30                      31
# 33         Delhi                    1327                    1300
# 34   Lakshadweep                       1                       0
# 35    Puducherry                      76                      70
#
#     Fatal Accidents - 2018  Accidents - 2016  Accidents - 2017  \
# 31                      30                70                67
# 32                      34                65                70
# 33                    1399              6652              5918
# 34                       1                 1                 1
# 35                     105               519               599
#
#     Accidents - 2018 - Number  Killed - 2016  Killed - 2017  \
# 31                         47             46             43
# 32                         76             36             31
# 33                       5732           1353           1317
# 34                          3              1              0
# 35                        690             78             77
#
#     Killed - 2018 - Number  Injured - 2016  Injured - 2017  Injured - 2018
# 31                      32             130              60              43
# 32                      35              86              68              94
# 33                    1427            6504            5844            5382
# 34                       1               0               1               3
# 35                     105             535             659             694

# %% [markdown]
# **3. Change column name for 2018 Accidents and Killed**

# %%
df = df.rename(columns={'Accidents - 2018 - Number': 'Accidents - 2018', 'Killed - 2018 - Number': 'Killed - 2018'})

# %%
# Check if worked
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 35
# Data columns (total 13 columns):
# State/UT                  36 non-null object
# Fatal Accidents - 2016    36 non-null int64
# Fatal Accidents - 2017    36 non-null int64
# Fatal Accidents - 2018    36 non-null int64
# Accidents - 2016          36 non-null int64
# Accidents - 2017          36 non-null int64
# Accidents - 2018          36 non-null int64
# Killed - 2016             36 non-null int64
# Killed - 2017             36 non-null int64
# Killed - 2018             36 non-null int64
# Injured - 2016            36 non-null int64
# Injured - 2017            36 non-null int64
# Injured - 2018            36 non-null int64
# dtypes: int64(12), object(1)
# memory usage: 3.9+ KB

# %% [markdown]
# **4. Remove Spaces and '-' from column names**

# %%
df.columns = df.columns.str.replace(' ', '')
df.columns = df.columns.str.replace('-', '')

# %%
# Check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 35
# Data columns (total 13 columns):
# State/UT              36 non-null object
# FatalAccidents2016    36 non-null int64
# FatalAccidents2017    36 non-null int64
# FatalAccidents2018    36 non-null int64
# Accidents2016         36 non-null int64
# Accidents2017         36 non-null int64
# Accidents2018         36 non-null int64
# Killed2016            36 non-null int64
# Killed2017            36 non-null int64
# Killed2018            36 non-null int64
# Injured2016           36 non-null int64
# Injured2017           36 non-null int64
# Injured2018           36 non-null int64
# dtypes: int64(12), object(1)
# memory usage: 3.9+ KB

# %%
df.head()
# Out:
#             State/UT  FatalAccidents2016  FatalAccidents2017  \
# 0     Andhra Pradesh                3328                3192
# 1  Arunachal Pradesh                  37                  33
# 2              Assam                 616                 710
# 3              Bihar                1299                1422
# 4       Chhattisgarh                1622                1836
#
#    FatalAccidents2018  Accidents2016  Accidents2017  Accidents2018  \
# 0                2619          11078          11526           9955
# 1                  46             79             83             94
# 2                 716           1958           2277           2174
# 3                2075           2650           2714           3495
# 4                2049           6374           6483           6733
#
#    Killed2016  Killed2017  Killed2018  Injured2016  Injured2017  Injured2018
# 0        3518        3350        2730        13707        12793         9121
# 1          47          35          61          148          107          109
# 2         596         762         744         1697         1880         1976
# 3        1451        1600        2204         1954         1966         2455
# 4        1801        2020        2140         5954         6027         6257

# %% [markdown]
# ## Save the data
# - Write to CSV file
# - On a database

# %%
# Writing to CSV file
df.to_csv('Cleaned.csv', index=False)

# %%
# Save to database

# Get a databse
# Here an sqlite database
import sqlalchemy as db

# Configure
engine = db.create_engine('sqlite:///accidents.sqlite', echo=False)

# Save to database
df.to_sql(name='accidents', con=engine, if_exists = 'append', index=False)
